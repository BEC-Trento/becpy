# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sys, os

# %%
sys.path.append(os.path.abspath('../'))
from libraries.Sis2 import readsis_quiet as readsis

# %%
atoms, probe = readsis('SD_oscillation_20170213_T175025_0_raw.sis', verbose=True)
# Out:
# You are opening the file: SD_oscillation_20170213_T175025_0_raw.sis

# %%
match = (slice(0,100), slice(0,100))

a = atoms[match].ravel()
b = probe[match].ravel()
l = np.dot(a,b)/np.dot(b,b)

# %%
l
# Out:
# 1.0068150969804464

# %%
od = np.log(l*probe/atoms)
plt.imshow(od)

# %% [raw]
# np.save('mypic2.npy', od)

# %% [markdown]
# --------

# %%
sis, _ = readsis('20161214-phase imprint-0018.sis', verbose=True)
sis = sis/(2**16/10)
# Out:
# You are opening the file: 20161214-phase imprint-0018.sis

# %%
plt.imshow(sis, cmap='gist_stern', vmin=0, )

# %%
np.save('../mypicture_spinor.npy', arr=sis)

# %%
sis.max()
# Out:
# 6.22772216796875
